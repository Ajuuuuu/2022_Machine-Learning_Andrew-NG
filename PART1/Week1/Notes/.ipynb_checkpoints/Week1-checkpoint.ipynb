# %% [markdown]
# ## 2.1 什么是机器学习
# 监督学习
# 无监督学习

# %% [markdown]
# ## 2.2 Supervised Learning 监督学习
# 监督学习需要对训练数据进行标记，以表示该数据的正确输出。算法通过对训练数据的学习来构建一个模型，以便对未知数据进行预测。监督学习的主要任务是回归或分类。
#    #### 回归是一种机器学习的任务，它的目的是预测一个连续的标签（例如价格）。回归算法通过学习输入特征与标签的关系，来生成一个连续的输出。
#    #### 分类是一种机器学习任务，目的是预测离散的标签（例如邮件是垃圾邮件还是非垃圾邮件）。分类算法通过学习输入特征与标签的关系，来生成一个离散的输出。

# %% [markdown]
# ## 2.3 Unsupervised Learning 无监督学习
#     无监督学习是一种机器学习方法，它不需要明确的目标变量或标签，而是通过从数据中提取有用信息来学习模型。 无监督学习的目的是找出数据之间的关系，并对数据进行分组，从而生成一个无监督的数据模型。

# %% [markdown]
# ## 3.1 Linear Regression 线性回归
#     training set:训练集
#     x = "input" variable or feature
#     y = "output" variable or "target" variable
#     m = number of training examples

# %% [markdown]
# ## 3.2 线性回归part2
#     training set + learning algorithm -> function
#     the function will output y_hat with a new x
#
#     But how to represent the function?
# #### ${f}_{w,b}=wx+b $

# %% [markdown]
# ## 3.3 Cost Function 代价函数
#     Cost function（代价函数）是机器学习中一个重要的概念。它是一个评估模型的指标，表示模型的预测值与真实值的差距。
#     In the function w,b are parameters
#
#     Find w and b which make y_hat is close to y
# #### cost function $ J\left ( {w,b} \right ) $ = $ \frac{\sum ^{m}_{i=1} {\left ( {{y}^{(i)}_{hat}-{y}^{(i)}} \right )^{2}} }{2m}$  this function also called squared error cost function

# %% [markdown]
# ## 3.4 What cost function really doing? 理解代价函数
#     Find w and b that makes J as small as possible
#
#     We first consider y = wx
#  #### the cost function is: $ J\left ( {w} \right ) $ = $ \frac{\sum ^{m}_{i=1} {\left ( {{wx}^{(i)}-{y}^{(i)}} \right )^{2}} }{2m}$

# %% [markdown]
# ## 3.5 Visualizing the Cost Function 可视化代价函数
# ## 3.6 可视化举例

# %% [markdown]
# ## 4.1 Gradient Descent 梯度下降
#     1. Start with some w,b
#     2. Keep changing w,b to reduce J(w,b)
#     3. Until we settle at or near a minimum

# %% [markdown]
# ## 4.2 Implementing GD 梯度下降的实现
#  $ w=w-\alpha \frac {\partial } {\partial w}J(w,b) $
#
#  $ \frac {\partial } {\partial w}J(w,b) $ decide the direction
#  and the $ \alpha $ means learning rate
#
# $ w=w-\alpha \frac {\partial } {\partial w}J(w,b) $
#
# $ b=b-\alpha \frac {\partial } {\partial b}J(w,b) $
#     repeat the them until convergence(收敛)
#
#
#     the correct way : Simultaneous update(同时更新)
#     tmp_w = w - ...
#     tmp_b = b - ...
#     w = tmp_w
#     b = tmp_b
#     do not use the tmp_w to count the new tmp_b

# %% [markdown]
# ## 4.3 GD Intuition 理解梯度下降
# $ \alpha $ : learning rate
#
# $\alpha$ >0
#
#     同时对于这里的偏导，我们想象对于b一定时，对于所有的w存在于同一个平面
#     此时平面上的w的图像，我们可以沿着梯度和步长得到它的极小值
#     这就是求偏导的原因

# %% [markdown]
# ## 4.4 Learning Rate 学习率
#     If it's too small: need a lots of steps    be very slow
#     If it's too large: you may never reach minimum

# %% [markdown]
# ## 4.5 GD for Linear Regression 用于线性回归的梯度下降
# ![img1](./img/01.png)
#
#     将式子依次带入 然后求偏导可以得到
#
# ![img2](./img./02.png)
#
#     然后重复这两式，直至收敛
#
#
#     同时，对于Squared error cost function
#     此代价函数是一个凸函数，意味着有且只有一个最小值，没有局部极小值

# %% [markdown]
# ## 4.6 Running GD 运行梯度下降
#     "Batch" GD : 批量梯度下降

# %% [markdown]
# ## try GD

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# 定义训练数据集
x_train = np.array([1.0, 2.0, 3.0])
y_train = np.array([300.0, 500.0, 650.0])

# 定义cost function
def cost_function(x, y, w, b):
    cost = 0
    m = len(x)
    for i in range(m):
        y_temp = w*x[i] + b
        cost = cost + (y_temp - y[i])**2
    return cost/(2*m)

# 计算参数偏导值
def compute_gradient(x, y, w, b):
    m = len(x)
    dw = 0
    db = 0

    for i in range(m):
        f_temp = w*x[i] + b
        dw = dw + (f_temp - y[i]) * x[i]
        db = db + (f_temp - y[i])

    return dw/m , db/m

# 计算
def gradient_descent(x, y, w_init, b_init, times, alpha):
    w = w_init
    b = b_init
    J_history = [cost_function(x, y, w, b)]
    P_history = [[w,b]]

    for i in range(times):
        dw , db = compute_gradient(x, y, w, b)
        w = w - alpha * dw
        b = b - alpha * db

        J_history.append(cost_function(x, y, w, b))
        P_history.append([w,b])

    return w, b, J_history, P_history

# 给定必须的初值
w_init = 0
b_init = 0
times = 1000
alpha = 0.05
w_final, b_final, J_history, P_history = gradient_descent(x_train, y_train, w_init, b_init, times, alpha)

# 输出结果
print(w_final, b_final)
print(J_history)
print(P_history)

m = len(x_train)
y_hat = []
for i in range(m):
    y = w_final*x_train[i] + b_final
    y_hat.append(y)

# 画图对比
plt.plot(x_train, y_train, 'r-', label='train data')
plt.plot(x_train, y_hat, 'b-', label='GD')

plt.show()
# Out:
# 175.05006296271304 133.2195284518034
# [127083.33333333333, 66478.35648148149, 34825.82905735597, 18294.05668091099, 9659.280308021685, 5148.8099038018945, 2792.315278885208, 1560.7690710826164, 916.7499734072911, 579.5835059115706, 402.68412598335993, 309.49575737642607, 260.0360065521333, 233.42350104553475, 218.75259418146265, 210.32757632983785, 205.17368778552762, 201.7372170621795, 199.20661249994305, 197.1579251042546, 195.36963704050288, 193.72595370452885, 192.16629689686488, 190.65892704643989, 189.18716710358535, 187.74220779762754, 186.31935008677968, 184.9160427207975, 183.5308573217424, 182.1629530943703, 180.81179725129246, 179.47701898823345, 178.15833320751497, 176.85550066847907, 175.5683071624753, 174.29655262377833, 173.04004542983273, 171.79859941181735, 170.57203228087303, 169.36016479381144, 168.16282030518786, 166.9798245212984, 165.8110053597722, 164.65619286446497, 163.51521914936947, 162.3879183578224, 161.27412662983986, 160.17368207382228, 159.08642474069987, 158.01219659945272, 156.95084151351563, 155.9022052177422, 154.86613529581726, 153.84248115800764, 152.8310940192301, 151.83182687739577, 150.8445344920384, 149.8690733631924, 148.90530